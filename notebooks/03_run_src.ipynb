# %%
# auto reload the Python source in ../src/anndata_repr/__init__.py without needing to restart kernel
# %load_ext autoreload
# %autoreload 2

# %%
# retrieve dataset
from anndata_repr import read_h5ad
adata = read_h5ad("../data/scverse-getting-started-anndata-pbmc3k_processed.h5ad")
adata
# Out:
# [5.07960576e-02 2.14556482e-01 4.90144049e-01 1.55799848e-01
#  5.34495830e-02 2.61561789e-02 6.44427597e-03 2.27445034e-03
#  3.79075057e-04]
# [0.00796058 0.08301744 0.23464746 0.27862017 0.19484458 0.10879454
#  0.05572403 0.02312358 0.01326763]
# [0.1383624  0.46550417 0.26914329 0.07846854 0.02767248 0.0136467
#  0.0045489  0.0015163  0.00113723]
# [0.84737071 0.08700565 0.02677097 0.0111256  0.00851804 0.0041721
#  0.00295524 0.0027814  0.0093003 ]
# AnnData object with n_obs × n_vars = 2638 × 11505
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain_cell_types'
#     var: 'gene_names', 'n_cells', 'gene_ids'
#     uns: 'louvain', 'louvain_colors', 'pca'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     layers: 'raw'
#     obsp: 'distances_all'
